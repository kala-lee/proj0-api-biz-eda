# %% [markdown]
# * [네이버 오픈 API 목록 - INTRO](https://developers.naver.com/products/intro/plan/plan.md)
# * [애플리케이션 - NAVER Developers](https://developers.naver.com/apps/#/list)

# %%
import os
import requests
import pandas as pd
import time
import logging
from tqdm import tqdm
from datetime import datetime
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# 환경변수 로드
load_dotenv()
# Out:
# False

# %% [markdown]
# pip install python-dotenv

# %% [markdown]
# pip install koreanize-matplotlib

# %%
import logging

# 로깅 설정 함수 정의
def setup_logging():
    logger = logging.getLogger()
    logger.setLevel(logging.INFO)

    # 파일 핸들러 추가 (로그 파일에 기록)
    file_handler = logging.FileHandler('program.log')
    file_handler.setLevel(logging.INFO)

    # 콘솔 핸들러 추가 (콘솔에 로그 출력)
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.INFO)

    # 포맷 설정
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)

    # 핸들러를 로거에 추가
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    return logger

# 로거 설정
logger = setup_logging()
logger.info("프로그램 시작")
# Out:
# 2024-12-23 19:24:12,672 - root - INFO - 프로그램 시작

# %% [markdown]
# # 로거 설정
# logger = setup_logging()
# logger.info("프로그램 시작")
#
# # 설정값 정의
# CATEGORIES = [
#     {"name": "패션의류", "param": ["50000000"]},
#     {"name": "화장품/미용", "param": ["50000002"]},
#     {"name": "디지털/가전", "param": ["50000003"]},
#     {"name": "가구/인테리어", "param": ["50000004"]},
#     {"name": "출산/육아", "param": ["50000005"]},
#     {"name": "스포츠/레저", "param": ["50000006"]},
#     {"name": "생활/건강", "param": ["50000007"]},
#     {"name": "여가/생활편의", "param": ["50000008"]},
#     {"name": "식품", "param": ["50000009"]},
#     {"name": "도서", "param": ["50000010"]}
# ]
#
# START_DATE = "2024-01-01"
# END_DATE = "2024-12-15"
# TIME_UNIT = "date"
# DEVICES = ["pc", "mobile"]
# GENDERS = ["f", "m"]
# AGES = ["10", "20", "30", "40", "50", "60"]
#
#
# # 환경변수에서 API 키 로드
# CLIENT_ID = "uD_1kctG8tlAmJx1XoRX"
# CLIENT_SECRET = "4PZh2CBqA1"
# URL = "https://openapi.naver.com/v1/datalab/shopping/categories"
#
# if not CLIENT_ID or not CLIENT_SECRET:
#     logger.error("CLIENT_ID 또는 CLIENT_SECRET이 설정되지 않았습니다. .env 파일을 확인하세요.")
#     exit(1)
#
#
# try:
#     # 데이터 수집
#     logger.info("데이터 수집 시작")
#     df = fetch_data(
#         CLIENT_ID, CLIENT_SECRET, URL, CATEGORIES,
#         START_DATE, END_DATE, TIME_UNIT,
#         DEVICES, GENDERS, AGES,
#         logger
#     )
#
#     if not df.empty:
#         # 원본 데이터 저장
#         df.to_csv("raw_shopping_data.csv", index=False)
#         logger.info("원본 데이터 저장 완료")
#
#         # 전처리된 데이터 저장
#         df.to_csv("processed_shopping_data.csv", index=False)
#         logger.info("전처리된 데이터 저장 완료")
#
#     else:
#         logger.error("수집된 데이터가 없습니다.")
#
# except Exception as e:
#     logger.error(f"프로그램 실행 중 오류 발생: {str(e)}")
#
# finally:
#     logger.info("프로그램 종료")

# %% [markdown]
# df = pd.read_csv('raw_shopping_data.csv')
# df

# %%
# 데이터 전처리
logger.info("데이터 전처리 시작")

# 결측치 확인
missing_values = df.isnull().sum()
logger.info(f"결측치 현황:\n{missing_values}")

# 이상치 확인 (ratio 값이 0-100 범위를 벗어나는 경우)
outliers = df[~df['ratio'].between(0, 100)]
logger.info(f"이상치 개수: {len(outliers)}")

# 데이터 타입 변환
df['date'] = pd.to_datetime(df['date'])
df['age_group'] = df['age_group'].astype(int)

# 기초 통계량 출력
logger.info("\n기초 통계량:")
logger.info(f"\n{df.describe()}")
# Out:
# 2024-12-23 19:24:12,756 - root - INFO - 데이터 전처리 시작
# 2024-12-23 19:24:12,756 - root - INFO - 데이터 전처리 시작
# 2024-12-23 19:24:12,766 - root - INFO - 결측치 현황:
# date         0
# category     0
# device       0
# gender       0
# age_group    0
# ratio        0
# dtype: int64
# 2024-12-23 19:24:12,766 - root - INFO - 결측치 현황:
# date         0
# category     0
# device       0
# gender       0
# age_group    0
# ratio        0
# dtype: int64
# 2024-12-23 19:24:12,769 - root - INFO - 이상치 개수: 0
# 2024-12-23 19:24:12,769 - root - INFO - 이상치 개수: 0
# 2024-12-23 19:24:12,785 - root - INFO -
# 기초 통계량:
# 2024-12-23 19:24:12,785 - root - INFO -
# 기초 통계량:
# 2024-12-23 19:24:12,799 - root - INFO -
#                                 date     age_group         ratio
# count                          39506  39506.000000  39506.000000
# mean   2024-06-19 20:13:01.491419136     35.151116     41.324336
# min              2024-01-01 00:00:00     10.000000      0.687330
# ...

# %%
# 데이터 타입 변환 및 날짜 관련 컬럼 생성
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month
df['dayofweek'] = df['date'].dt.dayofweek

df['dayofweekname'] = df['dayofweek'].map(lambda x: '월화수목금토일'[x])

# %%
df.describe()
# Out:
#                                 date     age_group         ratio  \
# count                          39506  39506.000000  39506.000000
# mean   2024-06-19 20:13:01.491419136     35.151116     41.324336
# min              2024-01-01 00:00:00     10.000000      0.687330
# 25%              2024-03-25 00:00:00     20.000000     25.080430
# 50%              2024-06-17 00:00:00     40.000000     42.565390
# 75%              2024-09-15 00:00:00     50.000000     56.212040
# max              2024-12-15 00:00:00     60.000000    100.000000
# std                              NaN     16.964825     19.608973
#
#               month     dayofweek
# count  39506.000000  39506.000000
# mean       6.142586      2.996532
# min        1.000000      0.000000
# 25%        3.000000      1.000000
# 50%        6.000000      3.000000
# 75%        9.000000      5.000000
# max       12.000000      6.000000
# std        3.315361      1.999801

# %% [markdown]
# ## 스포츠/레저 분석

# %% [markdown]
# ### 2023년 데이터

# %%
import requests
import json

CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")

# 네이버 API 자격 증명 정보
CLIENT_ID = 'MPXfJyDQEVDRagoqt2hv'
CLIENT_SECRET = 'pXeNS4zCHw'

# API URL 및 요청 헤더 설정
url = "https://openapi.naver.com/v1/datalab/shopping/categories"
headers = {
    "X-Naver-Client-Id": CLIENT_ID,
    "X-Naver-Client-Secret": CLIENT_SECRET,
    "Content-Type": "application/json"
}

# 요청 데이터 설정
data = {
    "startDate": "2023-01-01",
    "endDate": "2023-12-31",
    "timeUnit": "month",
    "category": [{"name": "여성패션", "param": ["50000000"]}],
    "device": "",
    "ages": ["10","20", "30", "40", "50", "60"],
    "gender": ""
}

# API 요청 보내기
response = requests.post(url, headers=headers, data=json.dumps(data))

# 응답받은 데이터 출력
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
else:
    print("Error Code:", response.status_code)
# Out:
# {
#     "startDate": "2023-01-01",
#     "endDate": "2023-12-31",
#     "timeUnit": "month",
#     "results": [
#         {
#             "title": "여성패션",
#             "category": [
#                 "50000000"
#             ],
#             "data": [
#                 {
#                     "period": "2023-01-01",
#                     "ratio": 83.47239
#                 },
#                 {
#                     "period": "2023-02-01",
#                     "ratio": 82.63156
#                 },
#                 {
#                     "period": "2023-03-01",
#                     "ratio": 97.9777
#                 },
#                 {
#                     "period": "2023-04-01",
#                     "ratio": 88.12811
#                 },
#                 {
#                     "period": "2023-05-01",
#                     "ratio": 87.3813
#                 },
#                 {
#                     "period": "2023-06-01",
#                     "ratio": 78.15542
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 이전에 받았던 JSON 데이터를 Pandas 데이터프레임으로 변환
results = data['results'][0]
df = pd.DataFrame(results['data'])

# 'period' 열을 datetime 형식으로 변환
df['period'] = pd.to_datetime(df['period'])

# 데이터프레임 확인 (상위 5개 데이터)
df.head()
# Out:
#       period     ratio
# 0 2023-01-01  83.47239
# 1 2023-02-01  82.63156
# 2 2023-03-01  97.97770
# 3 2023-04-01  88.12811
# 4 2023-05-01  87.38130

# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import time
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

# %%
month_list = []
for i in range(1, 13):
    month = str(i).zfill(2)  # 숫자를 2자리로 만들기 위해 zfill 함수 사용
    month_list.append(month)

print(month_list)
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
chrome_options = webdriver.ChromeOptions()
service=Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
# Out:
# 2024-12-23 21:21:35,536 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:21:35,536 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:21:40,296 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:21:40,296 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:21:44,543 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:21:44,543 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:21:44,718 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache
# 2024-12-23 21:21:44,718 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache

# %%
driver.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")
time.sleep(2)

# %%
# 네이버 데이터랩 접속
print("네이버 데이터랩 접속 중...")
driver.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")
time.sleep(2)

# 스크롤 버튼 클릭
print("스크롤 버튼 클릭 중...")
scroll_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span'  # 버튼 XPath
scroll_button = driver.find_element(By.XPATH, scroll_button_xpath)
scroll_button.click()  # 버튼 클릭
time.sleep(2)  # 클릭 후 로드 대기

# "스포츠/레저" 항목 선택
print("스포츠/레저 항목 선택 중...")
sports_category_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li[8]/a'  # 스포츠/레저 항목 XPath
sports_category_element = driver.find_element(By.XPATH, sports_category_xpath)
sports_category_element.click()  # 항목 클릭
time.sleep(2)  # 항목 선택 후 대기

# 1년 버튼 클릭
print("1년 버튼 클릭 중...")
additional_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[1]/span/label[3]'  # 추가 버튼 XPath
additional_button = driver.find_element(By.XPATH, additional_button_xpath)
additional_button.click()  # 버튼 클릭
time.sleep(2)  # 버튼 클릭 후 대기

# 기간 선택
# 시작년도 선택
print("첫 번째 드롭다운 버튼 클릭 중...")
first_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/span'
first_dropdown_button = driver.find_element(By.XPATH, first_dropdown_button_xpath)
first_dropdown_button.click()  # 드롭다운 열기
time.sleep(2)  # 대기

print("첫 번째 드롭다운 항목 선택 중...")
first_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/ul/li[6]/a'
first_dropdown_item = driver.find_element(By.XPATH, first_dropdown_item_xpath)
first_dropdown_item.click()  # 항목 선택
time.sleep(2)  # 선택 후 대기

# 종료년도 선택택
print("두 번째 드롭다운 버튼 클릭 중...")
second_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/span'
second_dropdown_button = driver.find_element(By.XPATH, second_dropdown_button_xpath)
second_dropdown_button.click()  # 드롭다운 열기
time.sleep(2)  # 대기

print("두 번째 드롭다운 항목 선택 중...")
second_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/ul/li[2]/a'
second_dropdown_item = driver.find_element(By.XPATH, second_dropdown_item_xpath)
second_dropdown_item.click()  # 항목 선택
time.sleep(2)  # 선택 후 대기

# 기기, 성별, 연령 설정
print("기기 전체, 성별 전체, 연령 전체 선택 중...")
driver.find_element(By.XPATH, '//*[@id="18_device_0"]').click()  # 기기 전체
driver.find_element(By.XPATH, '//*[@id="19_gender_0"]').click()  # 성별 전체
driver.find_element(By.XPATH, '//*[@id="20_age_0"]').click()     # 연령 전체
time.sleep(1)

# 조회 버튼 클릭
print("조회하기 버튼 클릭 중...")
submit_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/a')
submit_button.click()
time.sleep(2)
# Out:
# 네이버 데이터랩 접속 중...
# 스크롤 버튼 클릭 중...
# 스포츠/레저 항목 선택 중...
# 1년 버튼 클릭 중...
# 첫 번째 드롭다운 버튼 클릭 중...
# 첫 번째 드롭다운 항목 선택 중...
# 두 번째 드롭다운 버튼 클릭 중...
# 두 번째 드롭다운 항목 선택 중...
# 기기 전체, 성별 전체, 연령 전체 선택 중...
# 조회하기 버튼 클릭 중...

# %%
# "스포츠/레저" 항목 선택
print("스크롤 버튼 클릭 중...")
scroll_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span'  # 버튼 XPath
scroll_button = driver.find_element(By.XPATH, scroll_button_xpath)
scroll_button.click()  # 버튼 클릭
time.sleep(2)  # 클릭 후 로드 대기
# Out:
# 스크롤 버튼 클릭 중...

# %%
# "스포츠/레저" 항목 선택
print("스포츠/레저 항목 선택 중...")
sports_category_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li[8]/a'  # 스포츠/레저 항목 XPath
sports_category_element = driver.find_element(By.XPATH, sports_category_xpath)
sports_category_element.click()  # 항목 클릭
time.sleep(2)  # 항목 선택 후 대기
# Out:
# 스포츠/레저 항목 선택 중...

# %%
# 기기, 성별, 연령 설정
print("기기 전체, 성별 전체, 연령 전체 선택 중...")
driver.find_element(By.XPATH, '//*[@id="18_device_0"]').click()  # 기기 전체
driver.find_element(By.XPATH, '//*[@id="19_gender_0"]').click()  # 성별 전체
driver.find_element(By.XPATH, '//*[@id="20_age_0"]').click()     # 연령 전체
time.sleep(1)
# Out:
# 기기 전체, 성별 전체, 연령 전체 선택 중...

# %%
# 1년 버튼 클릭
print("1년 버튼 클릭 중...")
additional_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[1]/span/label[3]'  # 추가 버튼 XPath
additional_button = driver.find_element(By.XPATH, additional_button_xpath)
additional_button.click()  # 버튼 클릭
time.sleep(2)  # 버튼 클릭 후 대기
# Out:
# 1년 버튼 클릭 중...

# %%
# 첫 번째 드롭다운 선택
print("첫 번째 드롭다운 버튼 클릭 중...")
first_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/span'
first_dropdown_button = driver.find_element(By.XPATH, first_dropdown_button_xpath)
first_dropdown_button.click()  # 드롭다운 열기
time.sleep(2)  # 대기

print("첫 번째 드롭다운 항목 선택 중...")
first_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/ul/li[6]/a'
first_dropdown_item = driver.find_element(By.XPATH, first_dropdown_item_xpath)
first_dropdown_item.click()  # 항목 선택
time.sleep(2)  # 선택 후 대기

# 두 번째 드롭다운 선택
print("두 번째 드롭다운 버튼 클릭 중...")
second_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/span'
second_dropdown_button = driver.find_element(By.XPATH, second_dropdown_button_xpath)
second_dropdown_button.click()  # 드롭다운 열기
time.sleep(2)  # 대기

print("두 번째 드롭다운 항목 선택 중...")
second_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/ul/li[2]/a'
second_dropdown_item = driver.find_element(By.XPATH, second_dropdown_item_xpath)
second_dropdown_item.click()  # 항목 선택
time.sleep(2)  # 선택 후 대기
# Out:
# 첫 번째 드롭다운 버튼 클릭 중...
# 첫 번째 드롭다운 항목 선택 중...
# 두 번째 드롭다운 버튼 클릭 중...
# 두 번째 드롭다운 항목 선택 중...

# %%
# 조회 버튼 클릭
print("조회하기 버튼 클릭 중...")
submit_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/a')
submit_button.click()
time.sleep(2)

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# === 1. ChromeDriver 설정 === #
def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')
    chrome_options.add_argument('--headless')  # 필요 시 브라우저 숨기기
    chrome_options.add_argument('--start-maximized')
    service = Service(ChromeDriverManager().install())  # webdriver_manager 라이브러리 활용
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver


# === 2. 네이버 데이터랩 크롤링 === #
def crawl_datalab():
    driver = setup_driver()
    try:
        # 네이버 데이터랩 접속
        print("네이버 데이터랩 접속 중...")
        driver.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")
        time.sleep(2)

        # 스크롤 버튼 클릭
        print("스크롤 버튼 클릭 중...")
        scroll_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span'  # 버튼 XPath
        scroll_button = driver.find_element(By.XPATH, scroll_button_xpath)
        scroll_button.click()  # 버튼 클릭
        time.sleep(2)  # 클릭 후 로드 대기

        # "스포츠/레저" 항목 선택
        print("스포츠/레저 항목 선택 중...")
        sports_category_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li[8]/a'  # 스포츠/레저 항목 XPath
        sports_category_element = driver.find_element(By.XPATH, sports_category_xpath)
        sports_category_element.click()  # 항목 클릭
        time.sleep(2)  # 항목 선택 후 대기

        # 1년 버튼 클릭
        print("1년 버튼 클릭 중...")
        additional_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[1]/span/label[3]'  # 추가 버튼 XPath
        additional_button = driver.find_element(By.XPATH, additional_button_xpath)
        additional_button.click()  # 버튼 클릭
        time.sleep(2)  # 버튼 클릭 후 대기

        # 기기, 성별, 연령 설정
        print("기기 전체, 성별 전체, 연령 전체 선택 중...")
        driver.find_element(By.XPATH, '//*[@id="18_device_0"]').click()  # 기기 전체
        driver.find_element(By.XPATH, '//*[@id="19_gender_0"]').click()  # 성별 전체
        driver.find_element(By.XPATH, '//*[@id="20_age_0"]').click()     # 연령 전체
        time.sleep(1)

        # 조회 버튼 클릭
        print("조회하기 버튼 클릭 중...")
        submit_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/a')
        submit_button.click()
        time.sleep(2)

        # 데이터 크롤링 시작
        print("데이터 크롤링 시작...")
        rows = []  # 데이터를 저장할 리스트

        # 총 25페이지 크롤링
        for page in range(25):  # range(0, 25): 25 페이지
            print(f"{page + 1} 페이지 크롤링 중...")

            for item in range(1, 21):  # 한 페이지당 20개 아이템
                xpath = f'//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[1]/ul/li[{item}]/a'
                try:
                    result = driver.find_element(By.XPATH, xpath).text.split('\n')  # 순위, 키워드 데이터 추출
                    rank, keyword = result[0], result[1]
                    rows.append([rank, keyword])  # 데이터를 리스트에 저장
                except Exception as e:
                    print(f"Error on page {page + 1}, item {item}: {e}")
                time.sleep(0.1)  # 약간의 대기 시간

            # 다음 페이지 버튼 클릭
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/a[2]')
                next_button.click()
                time.sleep(2)
            except Exception as e:
                print(f"다음 페이지 버튼을 찾을 수 없습니다 (종료): {e}")
                break

        # DataFrame 생성 및 CSV 저장
        df = pd.DataFrame(rows, columns=["Rank", "Keyword"])
        df.to_csv("naverkeyword_top500_2024_sports.csv", index=False, encoding="utf-8-sig")  # UTF-8-SIG로 저장
        print("데이터 저장 완료: naverkeyword_top500_2024_sports.csv")

    finally:
        driver.quit()
        print("드라이버 종료")


# === 3. 실행 === #
if __name__ == "__main__":
    crawl_datalab()
# Out:
# 2024-12-23 21:05:52,359 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:05:52,359 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:05:56,870 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:05:56,870 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:05:57,018 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:05:57,018 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:05:57,184 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache
# 2024-12-23 21:05:57,184 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache
# 네이버 데이터랩 접속 중...
# 스크롤 버튼 클릭 중...
# 스포츠/레저 항목 선택 중...
# 1년 버튼 클릭 중...
# 기기 전체, 성별 전체, 연령 전체 선택 중...
# 조회하기 버튼 클릭 중...
# 데이터 크롤링 시작...
# 1 페이지 크롤링 중...
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# === 1. ChromeDriver 설정 === #
def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')
    chrome_options.add_argument('--headless')  # 필요 시 브라우저 숨기기
    chrome_options.add_argument('--start-maximized')
    service = Service(ChromeDriverManager().install())  # webdriver_manager 라이브러리 활용
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver


# === 2. 네이버 데이터랩 크롤링 === #
def crawl_datalab():
    driver = setup_driver()
    try:
        # 네이버 데이터랩 접속
        print("네이버 데이터랩 접속 중...")
        driver.get("https://datalab.naver.com/shoppingInsight/sCategory.naver")
        time.sleep(2)

        # 스크롤 버튼 클릭
        print("스크롤 버튼 클릭 중...")
        scroll_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/span'  # 버튼 XPath
        scroll_button = driver.find_element(By.XPATH, scroll_button_xpath)
        scroll_button.click()  # 버튼 클릭
        time.sleep(2)  # 클릭 후 로드 대기

        # "스포츠/레저" 항목 선택
        print("스포츠/레저 항목 선택 중...")
        sports_category_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[1]/div/div[1]/ul/li[8]/a'  # 스포츠/레저 항목 XPath
        sports_category_element = driver.find_element(By.XPATH, sports_category_xpath)
        sports_category_element.click()  # 항목 클릭
        time.sleep(2)  # 항목 선택 후 대기

        # 1년 버튼 클릭
        print("1년 버튼 클릭 중...")
        additional_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[1]/span/label[3]'  # 추가 버튼 XPath
        additional_button = driver.find_element(By.XPATH, additional_button_xpath)
        additional_button.click()  # 버튼 클릭
        time.sleep(2)  # 버튼 클릭 후 대기

        # 기간 선택
        # 시작년도 선택
        print("첫 번째 드롭다운 버튼 클릭 중...")
        first_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/span'
        first_dropdown_button = driver.find_element(By.XPATH, first_dropdown_button_xpath)
        first_dropdown_button.click()  # 드롭다운 열기
        time.sleep(2)  # 대기
        
        print("첫 번째 드롭다운 항목 선택 중...")
        first_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[1]/div[1]/ul/li[6]/a'
        first_dropdown_item = driver.find_element(By.XPATH, first_dropdown_item_xpath)
        first_dropdown_item.click()  # 항목 선택
        time.sleep(2)  # 선택 후 대기
        
        # 종료년도 선택택
        print("두 번째 드롭다운 버튼 클릭 중...")
        second_dropdown_button_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/span'
        second_dropdown_button = driver.find_element(By.XPATH, second_dropdown_button_xpath)
        second_dropdown_button.click()  # 드롭다운 열기
        time.sleep(2)  # 대기
        
        print("두 번째 드롭다운 항목 선택 중...")
        second_dropdown_item_xpath = '//*[@id="content"]/div[2]/div/div[1]/div/div/div[2]/div[2]/span[3]/div[1]/ul/li[2]/a'
        second_dropdown_item = driver.find_element(By.XPATH, second_dropdown_item_xpath)
        second_dropdown_item.click()  # 항목 선택
        time.sleep(2)  # 선택 후 대기

        # 기기, 성별, 연령 설정
        print("기기 전체, 성별 전체, 연령 전체 선택 중...")
        driver.find_element(By.XPATH, '//*[@id="18_device_0"]').click()  # 기기 전체
        driver.find_element(By.XPATH, '//*[@id="19_gender_0"]').click()  # 성별 전체
        driver.find_element(By.XPATH, '//*[@id="20_age_0"]').click()     # 연령 전체
        time.sleep(1)

        # 조회 버튼 클릭
        print("조회하기 버튼 클릭 중...")
        submit_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[1]/div/a')
        submit_button.click()
        time.sleep(2)

        # 데이터 크롤링 시작
        print("데이터 크롤링 시작...")
        rows = []  # 데이터를 저장할 리스트

        # 총 25페이지 크롤링
        for page in range(25):  # range(0, 25): 25 페이지
            print(f"{page + 1} 페이지 크롤링 중...")

            for item in range(1, 21):  # 한 페이지당 20개 아이템
                xpath = f'//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[1]/ul/li[{item}]/a'
                try:
                    result = driver.find_element(By.XPATH, xpath).text.split('\n')  # 순위, 키워드 데이터 추출
                    rank, keyword = result[0], result[1]
                    rows.append([rank, keyword])  # 데이터를 리스트에 저장
                except Exception as e:
                    print(f"Error on page {page + 1}, item {item}: {e}")
                time.sleep(0.1)  # 약간의 대기 시간

            # 다음 페이지 버튼 클릭
            try:
                next_button = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/a[2]')
                next_button.click()
                time.sleep(2)
            except Exception as e:
                print(f"다음 페이지 버튼을 찾을 수 없습니다 (종료): {e}")
                break

        # DataFrame 생성 및 CSV 저장
        df = pd.DataFrame(rows, columns=["Rank", "Keyword"])
        df.to_csv("naverkeyword_top500_2023_sports.csv", index=False, encoding="utf-8-sig")  # UTF-8-SIG로 저장
        print("데이터 저장 완료: naverkeyword_top500_2023_sports.csv")

    finally:
        driver.quit()
        print("드라이버 종료")


# === 3. 실행 === #
if __name__ == "__main__":
    crawl_datalab()
# Out:
# 2024-12-23 21:23:08,966 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:23:08,966 - WDM - INFO - ====== WebDriver manager ======
# 2024-12-23 21:23:13,520 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:23:13,520 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:23:13,657 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:23:13,657 - WDM - INFO - Get LATEST chromedriver version for google-chrome
# 2024-12-23 21:23:13,834 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache
# 2024-12-23 21:23:13,834 - WDM - INFO - Driver [C:\Users\eunju\.wdm\drivers\chromedriver\win64\131.0.6778.204\chromedriver-win32/chromedriver.exe] found in cache
# 네이버 데이터랩 접속 중...
# 스크롤 버튼 클릭 중...
# 스포츠/레저 항목 선택 중...
# 1년 버튼 클릭 중...
# 첫 번째 드롭다운 버튼 클릭 중...
# 첫 번째 드롭다운 항목 선택 중...
# 두 번째 드롭다운 버튼 클릭 중...
# 두 번째 드롭다운 항목 선택 중...
# ...

# %%
df_2024_sports = pd.read_csv('naverkeyword_top500_2024_sports.csv')
df_2024_sports
# Out:
#      Rank    Keyword
# 0       1        등산화
# 1       2      무릎보호대
# 2       3    노스페이스패딩
# 3       4      전기자전거
# 4       5        수영복
# ..    ...        ...
# 495   496    헬스스트랩프로
# 496   497  노스페이스눕시패딩
# 497   498   노스페이스미니샷
# 498   499       카라비너
# 499   500       고체연료
#
# [500 rows x 2 columns]

# %%
df_2023_sports = pd.read_csv('naverkeyword_top500_2023_sports.csv')
df_2023_sports
# Out:
#      Rank     Keyword
# 0       1         등산화
# 1       2         풋살화
# 2       3         수영복
# 3       4          핫팩
# 4       5     노스페이스패딩
# ..    ...         ...
# 495   496        몽벨패딩
# 496   497      그라운드시트
# 497   498  타이틀리스트드라이버
# 498   499      스파인코렉터
# 499   500         볼링화
#
# [500 rows x 2 columns]

# %%
# year 열 추가 및 값 할당
df_2024_sports['year'] = 2024

# category 열 추가 및 값 할당
df_2024_sports['category'] = '스포츠레저'

# %%
df_2024_sports.to_csv(r'C:\Users\eunju\OneDrive\문서\naverkeyword_top500_2024_sports.csv', index=False, encoding='utf-8-sig')

# %%
# year 열 추가 및 값 할당
df_2023_sports['year'] = 2023

# category 열 추가 및 값 할당
df_2023_sports['category'] = '스포츠레저'

# %%
df_2023_sports.to_csv(r'C:\Users\eunju\OneDrive\문서\naverkeyword_top500_2023_sports.csv', index=False, encoding='utf-8-sig')

# %%
# 두 DataFrame을 합치기 (union 방식)
df_sports_combined = pd.concat([df_2023_sports, df_2024_sports], ignore_index=True)
# Out:
#    Rank  Keyword  year category
# 0     1      등산화  2023    스포츠레저
# 1     2      풋살화  2023    스포츠레저
# 2     3      수영복  2023    스포츠레저
# 3     4       핫팩  2023    스포츠레저
# 4     5  노스페이스패딩  2023    스포츠레저

# %%
# 결과 확인
df_sports_combined.tail()
# Out:
#      Rank    Keyword  year category
# 995   496    헬스스트랩프로  2024    스포츠레저
# 996   497  노스페이스눕시패딩  2024    스포츠레저
# 997   498   노스페이스미니샷  2024    스포츠레저
# 998   499       카라비너  2024    스포츠레저
# 999   500       고체연료  2024    스포츠레저

# %%
df_sports_combined.to_csv(r'C:\Users\eunju\OneDrive\문서\naverkeyword_top500_2023to2024_sports.csv', index=False, encoding='utf-8-sig')

# %%
print(df_2023_sports.columns)
print(df_2024_sports.columns)
# Out:
# Index(['Rank', 'Keyword', 'year', 'category'], dtype='object')
# Index(['Rank', 'Keyword', 'year', 'category'], dtype='object')

# %%
# 2023년과 2024년 데이터를 병합
df = pd.merge(df_2023_sports[['Keyword', 'Rank', 'year']], df_2024_sports[['Keyword', 'Rank', 'year']], on='Keyword', suffixes=('_2023', '_2024'))

# 순위 차이 계산 (2024년 순위 - 2023년 순위)
df['Rank_Difference'] = df['Rank_2024'] - df['Rank_2023']

# 순위 차이가 가장 많이 상승한 키워드
df_sorted = df.sort_values(by='Rank_Difference', ascending=False)
# Out:
#        Keyword  Rank_2023  year_2023  Rank_2024  year_2024  Rank_Difference
# 137    아디다스축구화        138       2023        380       2024              242
# 250     k2바람막이        255       2023        472       2024              217
# 109      골키퍼장갑        110       2023        317       2024              207
# 188      k2롱패딩        192       2023        395       2024              203
# 248       등산장갑        253       2023        447       2024              194
# ..         ...        ...        ...        ...        ...              ...
# 398  천국의계단운동기구        466       2023        249       2024             -217
# 395      캐노피천막        463       2023        240       2024             -223
# 316         철봉        327       2023         93       2024             -234
# 389  노스페이스경량패딩        446       2023        196       2024             -250
# 378        넥쿨러        427       2023        137       2024             -290
#
# [416 rows x 6 columns]
# ...

# %%
df_sorted
# Out:
#        Keyword  Rank_2023  year_2023  Rank_2024  year_2024  Rank_Difference
# 137    아디다스축구화        138       2023        380       2024              242
# 250     k2바람막이        255       2023        472       2024              217
# 109      골키퍼장갑        110       2023        317       2024              207
# 188      k2롱패딩        192       2023        395       2024              203
# 248       등산장갑        253       2023        447       2024              194
# ..         ...        ...        ...        ...        ...              ...
# 398  천국의계단운동기구        466       2023        249       2024             -217
# 395      캐노피천막        463       2023        240       2024             -223
# 316         철봉        327       2023         93       2024             -234
# 389  노스페이스경량패딩        446       2023        196       2024             -250
# 378        넥쿨러        427       2023        137       2024             -290
#
# [416 rows x 6 columns]

# %% [markdown]
# 1.키워드 빈도 분석: 많이 언급된 키워드는 무엇인지 확인.<br>
# 2.키워드에 포함된 품목 분포 분석: 특정 품목(코트, 패딩 등)의 인기.<br>
# 3.연관 키워드 네트워크 시각화: 자주 함께 등장하는 연관 키워드 확인.<br>
# 4.키워드의 월별 트렌드 분석: 월별 키워드 관심도가 다른지 확인.<br>
# 5.구매 의향 키워드 추출: 구매 관련 키워드(예: 저렴, 추천 등)를 가진 키워드 사용 빈도 확인.<br>

# %% [markdown]
# ### 키워드 빈도 분석

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# Windows에서 사용할 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # 'Malgun Gothic'은 Windows에서 일반적으로 사용 가능한 한글 폰트입니다.

# 데이터 로드
df = pd.read_csv('naverkeyword_top500.csv', encoding='utf-8-sig')

# Null 값 제거 (필요 시)
df = df.dropna(subset=['Keyword'])

# 필터링할 키워드 목록 정의
exclude_keywords = ['여성패딩', '남성패딩', '패딩', '겨울패딩', '여성롱패딩', '남자패딩', '여자롱패딩']  # 제외할 키워드

# 제외할 키워드를 제거한 데이터
filtered_keywords = df[~df['Keyword'].isin(exclude_keywords)]

# 키워드 빈도 계산
keyword_counts = Counter(filtered_keywords['Keyword'])

# 상위 20개 키워드
most_common_keywords = keyword_counts.most_common(20)

# 데이터프레임으로 변환
most_common_df = pd.DataFrame(most_common_keywords, columns=['Keyword', 'Count'])

# 순위 라벨링 추가
most_common_df['Rank'] = most_common_df.index + 1

# 데이터 출력 확인
print(most_common_df)

# 점 그래프 시각화
plt.figure(figsize=(12, 8))

plt.scatter(most_common_df['Rank'], most_common_df['Keyword'], color='blue', alpha=0.7, s=100)

plt.title('Top 20 Keyword Rankings (Excluded Certain Keywords)', fontsize=16)
plt.xlabel('Rank', fontsize=12)
plt.ylabel('Keywords', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# 점 옆에 빈도 값 추가
for i, count in enumerate(most_common_df['Count']):
    plt.text(most_common_df['Rank'][i] + 1, i, str(count), va='center', fontsize=10)

plt.gca().invert_yaxis()

plt.show()
# Out:
#     Keyword  Count  Rank
# 0    몽클레어패딩      1     1
# 1       롱패딩      1     2
# 2        코트      1     3
# 3       무스탕      1     4
# 4       숏패딩      1     5
# 5     에르노패딩      1     6
# 6      패딩조끼      1     7
# 7      여성코트      1     8
# 8        점퍼      1     9
# 9    캐시미어코트      1    10
# 10  에고이스트패딩      1    11
# 11      원피스      1    12
# 12    버버리패딩      1    13
# 13    온앤온패딩      1    14
# 14   코듀로이팬츠      1    15
# 15    노르딕니트      1    16
# 16    니트원피스      1    17
# 17    여성숏패딩      1    18
# 18    나이키패딩      1    19
# 19       니트      1    20

# %%
import re

# 주요 품목 목록
items = ['코트', '패딩', '점퍼', '니트', '목도리', '부츠']

# 품목 빈도 카운트
item_counts = {item: 0 for item in items}

for keyword in df['Keyword']:
    for item in items:
        if item in keyword:
            item_counts[item] += 1

# 데이터프레임 변환
item_df = pd.DataFrame(list(item_counts.items()), columns=['Item', 'Count'])

# 시각화
plt.figure(figsize=(8, 5))
plt.bar(item_df['Item'], item_df['Count'], color='orange')
plt.title('Winter Item Frequency', fontsize=16)
plt.xlabel('Items', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
pip install WordCloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# 워드클라우드 데이터 준비
wordcloud_data = {keyword: count for keyword, count in keyword_counts.items()}

# 워드클라우드 생성
wordcloud = WordCloud(
    font_path='C:/Windows/Fonts/malgun.ttf',  # Windows에서 사용할 폰트 경로 (맑은 고딕)
    width=800,
    height=400,
    max_words=100,  # 최대 표시 단어 수
    background_color='white',  # 배경색
    colormap='cool',  # 색상 맵
    random_state=42
).generate_from_frequencies(wordcloud_data)

# 워드클라우드 시각화
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 좌표 제거
plt.title('Keyword Wordcloud', fontsize=20)
plt.show()
